# %%
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r'D:\7.30 PM DATA SCIENCE AND AI\DAILY SESSION MATERIALS\SEPT\7th\MOVIE RATINGS _ ADVANCE VISUALIZATION _ EDA 1\Movie-Rating.csv')

# %%
df
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
df.shape
# Out:
# (559, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions', 'Year']

# %%
df.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %% [markdown]
# ### Type Conversions:

# %%
df['Film'].head()
# Out:
# 0    (500) Days of Summer
# 1              10,000 B.C.
# 2               12 Rounds
# 3                127 Hours
# 4                17 Again
# Name: Film, dtype: object

# %%
df.Film = df.Film.astype('category')

# %%
df.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
df['Genre']
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: object

# %%
df.Genre = df.Genre.astype('category')

# %%
df['Genre']
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
df['Year']
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: int64

# %%
df.Year = df.Year.astype('category')

# %%
df['Year']
# Out:
# 0      2009
# 1      2008
# 2      2009
# 3      2010
# 4      2009
#        ...
# 554    2011
# 555    2009
# 556    2007
# 557    2009
# 558    2011
# Name: Year, Length: 559, dtype: category
# Categories (5, int64): [2007, 2008, 2009, 2010, 2011]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   CriticRating    559 non-null    int64
#  3   AudienceRating  559 non-null    int64
#  4   BudgetMillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
df.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %% [markdown]
# ### Visualizations:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
joint = sns.jointplot(data=df, x='CriticRating', y='AudienceRating')

# %%
hist = sns.jointplot(data=df, x='CriticRating', y='AudienceRating', kind='hist')

# %%
hex = joint = sns.jointplot(data=df, x='CriticRating', y='AudienceRating', kind='hex')

# %%
plt.figure(figsize=(8,6))
hist = plt.hist(df.AudienceRating, bins=15, color='orange')

# %%
hist_1 = sns.distplot(df.AudienceRating)

# %%
sns.set_style('darkgrid')
hist_2 = sns.distplot(df.AudienceRating)

# %%
sns.set_style('darkgrid')
sns.displot(df.CriticRating, color='magenta')

# %%
hist_3 = plt.hist(df.CriticRating, bins=10)

# %%
hist_4 = plt.hist(df.BudgetMillions)

# %%
df['Genre'].unique()
# Out:
# ['Comedy', 'Adventure', 'Action', 'Horror', 'Drama', 'Romance', 'Thriller']
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
df.Genre.nunique()
# Out:
# 7

# %%
action = plt.hist(df[df.Genre == 'Action'].BudgetMillions)

# %%
romance = plt.hist(df[df.Genre == 'Romance'].BudgetMillions)

# %%
plt.hist(df[df.Genre == 'Action'].BudgetMillions, bins=20)
plt.hist(df[df.Genre == 'Adventure'].BudgetMillions, bins=20)
plt.hist(df[df.Genre == 'Romance'].BudgetMillions, bins=20)

plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.hist([df[df.Genre == 'Action'].BudgetMillions, \
        df[df.Genre == 'Adventure'].BudgetMillions, \
        df[df.Genre == 'Romance'].BudgetMillions], bins=15, stacked=True)
plt.show()

# %%
for gen in df.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
v1 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating')

# %%
v2 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating', fit_reg=False)

# %%
v3 = sns.lmplot(data=df, x='CriticRating', y='AudienceRating', hue='Genre', fit_reg=False, aspect=2)

# %%
k1 = sns.kdeplot(df.CriticRating, df.AudienceRating)

# %%
k2 = sns.kdeplot(df.CriticRating, df.AudienceRating, shade=True)

# %%
k3 = sns.kdeplot(df.CriticRating, df.AudienceRating, shade_lowest=False, shade=True, cmap='Reds')

# %%
k4 = sns.kdeplot(df.CriticRating, df.AudienceRating, shade_lowest=False, shade=False, cmap='Reds')

# %%
k4 = sns.kdeplot(df.CriticRating, df.AudienceRating, shade_lowest=True, shade=True, cmap='Reds')

# %%
sns.set_style('whitegrid')
k5 = sns.kdeplot(df.CriticRating, df.AudienceRating, shade_lowest=True, shade=False, cmap='Reds')

# %%
sns.set_style('white')
k6 = sns.kdeplot(df.BudgetMillions, df.CriticRating)

# %%
k7 = sns.kdeplot(df.BudgetMillions, df.AudienceRating)

# %%
f, axes = plt.subplots(1,2, figsize=(14,6))
k11 = sns.kdeplot(df.BudgetMillions, df.CriticRating, ax=axes[0])
k12 = sns.kdeplot(df.BudgetMillions, df.AudienceRating, ax=axes[1])

# %%
f, axes = plt.subplots(2,1, figsize=(6,12))
k11 = sns.kdeplot(df.BudgetMillions, df.CriticRating, ax=axes[0])
k12 = sns.kdeplot(df.BudgetMillions, df.AudienceRating, ax=axes[1])

# %%
box = sns.boxplot(data=df, x='Genre', y='CriticRating')

# %%
box1 = sns.boxplot(data=df, x='Genre', y='AudienceRating')

# %%
box2 = sns.boxplot(data=df, x='Genre', y='BudgetMillions')

# %%
v = sns.violinplot(data=df, x='Genre', y='AudienceRating')

# %%
v1 = sns.violinplot(data=df, x='Genre', y='BudgetMillions')

# %%
box_11 = sns.boxplot(data=df[df.Genre == 'Action'], x='Year', y='CriticRating')

# %%
box_12 = sns.boxplot(data=df[df.Genre=='Romance'], x='Year', y='CriticRating')

# %%
box_13 = sns.boxplot(data=df[df.Genre=='Adventure'], x='Year', y='BudgetMillions')

# %%
box_14 = sns.boxplot(data=df[df.Genre=='Action'], x='Year', y='BudgetMillions')

# %%
box_14 = sns.boxplot(data=df[df.Genre=='Thriller'], x='Year', y='BudgetMillions')

# %%
f = sns.FacetGrid(df, row='Genre', col='Year', hue='Genre')

# %%
plt.scatter(df.CriticRating, df.AudienceRating)

# %%
f = sns.FacetGrid(data=df, row='Genre', col='Year', hue='Genre')
f = f.map(plt.scatter, 'CriticRating', 'AudienceRating' )

# %%
sns.set_style('darkgrid')

f, axes = plt.subplots (3,2, figsize = (15,15))

k1 = sns.kdeplot(df.BudgetMillions, df.AudienceRating, ax=axes[0,0])
k2 = sns.kdeplot(df.BudgetMillions, df.CriticRating, ax= axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z10 = sns.violinplot(data=df[df.Genre=='Action'], x='Year', y = 'CriticRating', ax=axes[1,0])

k00 = sns.kdeplot(df.CriticRating, df.AudienceRating,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k11 = sns.kdeplot(df.CriticRating, df.AudienceRating,cmap='Reds',ax = axes[2,0])

k21 = sns.boxplot(data=df, x='Genre', y='BudgetMillions')

plt.show()
